# %%
# %matplotlib notebook

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
url = "https://steamcharts.com/app/730"

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
table = soup.find("table", {"class": "common-table"})

# %%
csgo_df = pd.read_html(str(table))[0]

# %%
csgo_df.to_csv("csgo_players.csv", index=False)
csgo_df.head()
# Out:
#            Month  Avg. Players      Gain   % Gain  Peak Players
# 0   Last 30 Days     879445.31  +35970.8   +4.26%       1519457
# 1     March 2023     843474.54  38368.64   +4.77%       1519457
# 2  February 2023     805105.90  78955.61  +10.87%       1354248
# 3   January 2023     726150.29  96825.30  +15.39%       1199684
# 4  December 2022     629325.00   8319.00   +1.34%       1065079

# %%
ax =csgo_df.plot(x="Month", y="Avg. Players", kind="bar", width=.8, figsize=(20, 6))
ax.set_xticklabels(csgo_df['Month'], rotation=45, ha='right')
ax.invert_xaxis()
plt.title('Player Count for Counter-Strike: Global Offensive')
plt.xlabel('Month', fontsize=5)
plt.ylabel('Avg. Players')
ax.tick_params(axis='both', which='major', labelsize=5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000.0000529819079">

# %%
plt.savefig("CSGOPlayers.png")
plt.show()
