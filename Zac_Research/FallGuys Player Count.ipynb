# %%
# %matplotlib notebook

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
url = "https://steamcharts.com/app/1097150"

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
table = soup.find("table", {"class": "common-table"})

# %%
fg_df = pd.read_html(str(table))[0]

# %%
fg_df.to_csv("fall_guys.csv", index=False)
fg_df.head()
# Out:
#            Month  Avg. Players     Gain   % Gain  Peak Players
# 0   Last 30 Days       2257.16    -67.9   -2.92%          3496
# 1     March 2023       2325.08  -372.94  -13.82%          3711
# 2  February 2023       2698.03  -886.25  -24.73%          4386
# 3   January 2023       3584.27  -577.19  -13.87%          5399
# 4  December 2022       4161.46   231.37   +5.89%          9974

# %%
ax =fg_df.plot(x="Month", y="Avg. Players", kind="bar", width=.8, figsize=(10, 6))
ax.set_xticklabels(fg_df['Month'], rotation=45, ha='right')
ax.invert_xaxis()
plt.title('Player Count for Fall Guys')
plt.xlabel('Month', fontsize=5)
plt.ylabel('Avg. Players')
ax.tick_params(axis='both', which='major', labelsize=5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000.0000264909539">

# %%
plt.savefig("FallGuysPlayers.png")
plt.show()
